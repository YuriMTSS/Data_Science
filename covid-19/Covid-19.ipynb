# %% [markdown]
# # Base de dados: https://data.brasil.io/dataset/covid19/caso_full.csv.gz

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("caso_full.csv")
display(df)
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
df.dropna()
df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
df.rename(columns = {'new_confirmed': 'novos casos', 'new_deaths': 'novas mortes'}, inplace = True)

# %%
display(df)
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
df.describe()
# Out:
#        city_ibge_code  epidemiological_week  estimated_population  \
# count    3.840002e+06          3.853648e+06          3.840002e+06
# mean     3.228321e+06          2.021052e+05          8.116488e+04
# std      1.009499e+06          5.755437e+01          9.057809e+05
# min      1.100000e+01          2.020090e+05          7.760000e+02
# 25%      2.509107e+06          2.020440e+05          5.602000e+03
# 50%      3.144508e+06          2.021160e+05          1.219500e+04
# 75%      4.117297e+06          2.021400e+05          2.689900e+04
# max      5.300108e+06          2.022130e+05          4.628933e+07
#
#        estimated_population_2019  last_available_confirmed  \
# count               3.840002e+06              3.853648e+06
# mean                8.054619e+04              4.777532e+03
# std                 8.992380e+05              6.180363e+04
# min                 7.810000e+02              0.000000e+00
# 25%                 5.603000e+03              1.420000e+02
# ...

# %%
df.isnull().sum()
# Out:
# city                                             20119
# city_ibge_code                                   13646
# date                                                 0
# epidemiological_week                                 0
# estimated_population                             13646
# estimated_population_2019                        13646
# is_last                                              0
# is_repeated                                          0
# last_available_confirmed                             0
# last_available_confirmed_per_100k_inhabitants    29166
# last_available_date                                  0
# last_available_death_rate                            0
# last_available_deaths                                0
# order_for_place                                      0
# place_type                                           0
# state                                                0
# novos casos                                          0
# ...

# %% [markdown]
# # Gráfico de dispersão

# %%
sns.relplot(x = 'novos casos', y = 'novas mortes', data = df)

# %%
df.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'novos casos', 'novas mortes'],
#       dtype='object')

# %%
df.rename(columns = {'last_available_confirmed': 'último disponível confirmado', 'last_available_confirmed_per_100k_inhabitants': 'último disponível confirmado por 100 mil habitantes'}, inplace = True)

df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
sns.relplot(x = 'último disponível confirmado', y = 'último disponível confirmado por 100 mil habitantes', kind = 'line', data = df)

# %%
df.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'último disponível confirmado',
#        'último disponível confirmado por 100 mil habitantes',
#        'last_available_date', 'last_available_death_rate',
#        'last_available_deaths', 'order_for_place', 'place_type', 'state',
#        'novos casos', 'novas mortes'],
#       dtype='object')

# %%
df.rename(columns = {'estimated_population': 'população estimada', 'estimated_population_2019': 'população estimada 2019'}, inplace = True)

df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          população estimada  população estimada 2019  is_last  is_repeated  \
# ...

# %%
sns.catplot(x = 'população estimada', y = 'população estimada 2019', data = df)
