# %% [markdown]
# # Base de dados
#
# https://drive.google.com/file/d/1hGjTip0xp5x_QonPTpeYnPUmdFm4GGoE/view

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/IBOV_FUND_NEW_DRIVE.xlsx')
base.head()
# Out:
#   Ticker   Tipo                                   Empresa  \
# 0  CRDE3     ON                                    CR2 ON
# 1  MMAQ4     PN                      MINASMÁQUINAS S/A PN
# 2  SMLS3  ON NM                              SMILES ON NM
# 3  CGAS3     ON  COMPANHIA DE GÁS DE SÃO PAULO  COMGÁS ON
# 4  QUAL3  ON NM                           QUALICORP ON NM
#
#                      Setor                                           Subsetor  \
# 0  Construção e Engenharia                                   Construção Civil
# 1                 Comércio                             Material de Transporte
# 2                 Diversos                           Programas de Fidelização
# 3                      Gás                                                Gás
# 4                    Saúde  Serviços Médico  Hospitalares, Análises e Diag...
#
#    Valor de Mercado  Valor da Firma Último Balanço Processado  \
# 0      5.376840e+07    7.462600e+06                31/12/2019
# ...

# %%
base.dtypes
# Out:
# Ticker                                            object
# Tipo                                              object
# Empresa                                           object
# Setor                                             object
# Subsetor                                          object
# Valor de Mercado                                 float64
# Valor da Firma                                   float64
# Último Balanço Processado                         object
# Número de Ações                                  float64
# P/L                                              float64
# P/VP                                             float64
# P/EBIT                                           float64
# PSR                                              float64
# P/Ativos                                         float64
# P/Capital de Giro                                float64
# P/Ativo Circulante Liq.                          float64
# ...

# %%
base.describe()
# Out:
#        Valor de Mercado  Valor da Firma  Número de Ações           P/L  \
# count      4.370000e+02    3.920000e+02     4.370000e+02    437.000000
# mean       9.956480e+09    1.218981e+10     6.757512e+08     84.809817
# std        2.805145e+10    4.228887e+10     1.744210e+09    786.263949
# min        0.000000e+00    1.504440e+06     1.900000e+04      0.000000
# 25%        1.676730e+08    3.633628e+08     1.634400e+07      4.490000
# 50%        1.364010e+09    1.696560e+09     1.043440e+08      8.950000
# 75%        6.572310e+09    9.406408e+09     5.586990e+08     17.150000
# max        2.140210e+11    5.179700e+11     1.573510e+10  10332.500000
#
#               P/VP       P/EBIT          PSR    P/Ativos  P/Capital de Giro  \
# count   437.000000   389.000000   375.000000  391.000000         372.000000
# mean      9.416865    75.904190    26.153680    2.695038        7069.034032
# std      87.487840   464.003648   206.454939   19.506145       78813.377615
# ...

# %%
base.shape
# Out:
# (437, 44)

# %%
sns.catplot(y = 'Setor', kind = 'count', data = base, palette = 'ch:2', height = 10, aspect = 1, order = base['Setor'].value_counts().index)
#aspect = altura = 1/10 da largura

# %%
sns.catplot(y = 'Subsetor', kind = 'count', data = base, palette = 'ch:5', height = 20, aspect = 0.5, order = base['Subsetor'].value_counts().index)

# %%
base['Subsetor'].value_counts().plot(kind = 'barh', figsize = (20, 25))

# %%
chart = sns.catplot(x = 'Lucro Líquido', y = 'Subsetor', kind = 'box', data = base, height = 20, aspect = 1)

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Subsetor', y = 'Lucro Líquido', kind = 'box', data = base, height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Empresa', y = 'Lucro Líquido', kind = 'point', data = base.sort_values('Lucro Líquido', ascending = False).head(50), height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Subsetor', y = 'DY', kind = 'swarm', data = base, height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Empresa', y = 'DY', kind = 'point', data = base.sort_values('DY', ascending = False).head(50), height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Setor', y = 'P/L', kind = 'box', data = base.sort_values('P/L', ascending = True).head(50), height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Empresa', y = 'P/L', kind = 'point', data = base.sort_values('P/L', ascending = False).head(50), height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
filtro = base.Ticker.str.contains('PETR')
base[filtro]
# Out:
#     Ticker Tipo       Empresa                            Setor  \
# 91   PETR4   PN  PETROBRAS PN  Petróleo, Gás e Biocombustíveis
# 153  PETR3   ON  PETROBRAS ON  Petróleo, Gás e Biocombustíveis
#
#                                   Subsetor  Valor de Mercado  Valor da Firma  \
# 91   Exploração e/ou Refino e Distribuição      2.001030e+11    5.179700e+11
# 153  Exploração e/ou Refino e Distribuição      1.998420e+11    5.177090e+11
#
#     Último Balanço Processado  Número de Ações   P/L  ...  Dívida Bruta  \
# 91                 31/12/2019     1.304450e+10  4.99  ...  3.511610e+11
# 153                31/12/2019     1.304450e+10  4.98  ...  3.511610e+11
#
#      Dívida Líquida  Patrimônio Líquido  Receita Líquida          EBIT  \
# 91     3.178670e+11        2.955410e+11     3.022450e+11  9.599100e+10
# 153    3.178670e+11        2.955410e+11     3.022450e+11  9.599100e+10
#
#      Lucro Líquido  Carteira de Crédito  Depósitos  \
# ...

# %%
filtro = base.Ticker.str.contains('PETR')
df2 = base[-filtro]
df2
# Out:
#     Ticker   Tipo                                   Empresa  \
# 0    CRDE3     ON                                    CR2 ON
# 1    MMAQ4     PN                      MINASMÁQUINAS S/A PN
# 2    SMLS3  ON NM                              SMILES ON NM
# 3    CGAS3     ON  COMPANHIA DE GÁS DE SÃO PAULO  COMGÁS ON
# 4    QUAL3  ON NM                           QUALICORP ON NM
# ..     ...    ...                                       ...
# 432  MNDL3     ON                            MUNDIAL S/A ON
# 433  MWET3     ON                            WETZEL S.A. ON
# 434  MWET4     PN                            WETZEL S.A. PN
# 435  PINE3  ON N1                                Pine ON N1
# 436  TXRX3     ON                                 RENAUX ON
#
#                              Setor  \
# 0          Construção e Engenharia
# 1                         Comércio
# 2                         Diversos
# 3                              Gás
# 4                            Saúde
# ...

# %%
df3 = base[base['Dívida Líquida'] <= 0]
df3
# Out:
#     Ticker   Tipo                                   Empresa  \
# 10   BBSE3  ON NM                        BBSEGURIDADE ON NM
# 48   CSAB4     PN  COMPANHIA DE SEGUROS ALIANÇA DA BAHIA PN
# 89   CSAB3     ON  COMPANHIA DE SEGUROS ALIANÇA DA BAHIA ON
# 173  IRBR3  ON NM                        IRBBRASIL RE ON NM
# 352  ADHM3    NaN                               VITALYZE.ME
# 427  MAPT3     ON                          CIA MARCOPOLO ON
# 428  MAPT4     PN                          CIA MARCOPOLO PN
#
#                                   Setor                 Subsetor  \
# 10                Previdência e Seguros              Seguradoras
# 48                Previdência e Seguros              Seguradoras
# 89                Previdência e Seguros              Seguradoras
# 173               Previdência e Seguros              Seguradoras
# 352  Prods. de Uso Pessoal e de Limpeza  Produtos de Uso Pessoal
# 427                              Outros                   Outros
# ...

# %%
df3.sort_values('Dívida Líquida', ascending = True)
# Out:
#     Ticker   Tipo                                   Empresa  \
# 10   BBSE3  ON NM                        BBSEGURIDADE ON NM
# 48   CSAB4     PN  COMPANHIA DE SEGUROS ALIANÇA DA BAHIA PN
# 89   CSAB3     ON  COMPANHIA DE SEGUROS ALIANÇA DA BAHIA ON
# 173  IRBR3  ON NM                        IRBBRASIL RE ON NM
# 352  ADHM3    NaN                               VITALYZE.ME
# 427  MAPT3     ON                          CIA MARCOPOLO ON
# 428  MAPT4     PN                          CIA MARCOPOLO PN
#
#                                   Setor                 Subsetor  \
# 10                Previdência e Seguros              Seguradoras
# 48                Previdência e Seguros              Seguradoras
# 89                Previdência e Seguros              Seguradoras
# 173               Previdência e Seguros              Seguradoras
# 352  Prods. de Uso Pessoal e de Limpeza  Produtos de Uso Pessoal
# 427                              Outros                   Outros
# ...

# %%
df3 = base [ -(base.Ticker == 'CEPE3') & -(base.Ticker == 'CEPE5') & -(base.Ticker == 'CEPE6')]
df3
# Out:
#     Ticker   Tipo                                   Empresa  \
# 0    CRDE3     ON                                    CR2 ON
# 1    MMAQ4     PN                      MINASMÁQUINAS S/A PN
# 2    SMLS3  ON NM                              SMILES ON NM
# 3    CGAS3     ON  COMPANHIA DE GÁS DE SÃO PAULO  COMGÁS ON
# 4    QUAL3  ON NM                           QUALICORP ON NM
# ..     ...    ...                                       ...
# 432  MNDL3     ON                            MUNDIAL S/A ON
# 433  MWET3     ON                            WETZEL S.A. ON
# 434  MWET4     PN                            WETZEL S.A. PN
# 435  PINE3  ON N1                                Pine ON N1
# 436  TXRX3     ON                                 RENAUX ON
#
#                              Setor  \
# 0          Construção e Engenharia
# 1                         Comércio
# 2                         Diversos
# 3                              Gás
# 4                            Saúde
# ...

# %%
sns.set(font_scale = 1)
chart = sns.catplot(x = 'Empresa', y = 'P/L', kind = 'point', data = df3.sort_values('P/L', ascending = False).head(50), height = 8, aspect = 3)
chart.set_xticklabels(rotation = 45, horizontalalignment = 'right')

# %%
sns.set(font_scale = 1)
cor = base.corr()

plt.figure(figsize = (25,25))

ax = sns.heatmap(cor, vmin = -1, vmax = 1, center = 0, cmap = sns.diverging_palette(20, 200, n = 200), square = True)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0.5, 0, 'Valor de Mercado'),
#  Text(1.5, 0, 'Valor da Firma'),
#  Text(2.5, 0, 'Número de Ações'),
#  Text(3.5, 0, 'P/L'),
#  Text(4.5, 0, 'P/VP'),
#  Text(5.5, 0, 'P/EBIT'),
#  Text(6.5, 0, 'PSR'),
#  Text(7.5, 0, 'P/Ativos'),
#  Text(8.5, 0, 'P/Capital de Giro'),
#  Text(9.5, 0, 'P/Ativo Circulante Liq.'),
#  Text(10.5, 0, 'DY'),
#  Text(11.5, 0, 'EV/EBITDA'),
#  Text(12.5, 0, 'EV/EBIT'),
#  Text(13.5, 0, 'Crescimento da Receita (5 anos)'),
#  Text(14.5, 0, 'LPA'),
#  Text(15.5, 0, 'VPA'),
#  Text(16.5, 0, 'Margem Bruta'),
#  Text(17.5, 0, 'Margem EBIT'),
#  Text(18.5, 0, 'Margem Líquida'),
#  Text(19.5, 0, 'EBIT/Ativo'),
#  Text(20.5, 0, 'ROIC'),
#  Text(21.5, 0, 'ROE'),
#  Text(22.5, 0, 'Liquidez Corrente'),
#  Text(23.5, 0, 'Div Bruta/Patrimônio'),
#  Text(24.5, 0, 'Ativo de Giro'),
#  Text(25.5, 0, 'Ativo'),
#  Text(26.5, 0, 'Disponibilidades'),
#  Text(27.5, 0, 'Ativo Circulante'),
#  Text(28.5, 0, 'Dívida Bruta'),
#  Text(29.5, 0, 'Dívida Líquida'),
# ...

# %%
construtoras = base[base['Setor'] == 'Construção e Engenharia']
construtoras.head()
# Out:
#    Ticker Tipo                  Empresa                    Setor  \
# 0   CRDE3   ON                   CR2 ON  Construção e Engenharia
# 7   SOND6  PNB    SONDOTECNICA S/A. PNB  Construção e Engenharia
# 12  SOND5  PNA    SONDOTECNICA S/A. PNA  Construção e Engenharia
# 15  SOND3   ON     SONDOTECNICA S/A. ON  Construção e Engenharia
# 16  CYRE3   PN  CYRELA BRAZIL REALTY PN  Construção e Engenharia
#
#                  Subsetor  Valor de Mercado  Valor da Firma  \
# 0        Construção Civil      5.376840e+07    7.462600e+06
# 7   Engenharia Consultiva      7.622260e+07    4.882060e+07
# 12  Engenharia Consultiva      9.094600e+07    6.354400e+07
# 15  Engenharia Consultiva      9.340400e+07    6.600200e+07
# 16       Construção Civil      5.104720e+09    6.243940e+09
#
#    Último Balanço Processado  Número de Ações    P/L  ...  Dívida Bruta  \
# 0                 31/12/2019        2422000.0   5.76  ...  0.000000e+00
# ...

# %%
bx = construtoras.sort_values('EBIT', ascending = False)[['Ticker', 'EBIT']].set_index('Ticker').plot.bar(figsize = (15,8))
bx.set_xticklabels(bx.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'MRVE3'),
#  Text(0, 0, 'CYRE3'),
#  Text(0, 0, 'TEND3'),
#  Text(0, 0, 'DIRR3'),
#  Text(0, 0, 'EVEN3'),
#  Text(0, 0, 'JHSF3'),
#  Text(0, 0, 'TRIS3'),
#  Text(0, 0, 'JFEN3'),
#  Text(0, 0, 'EZTC3'),
#  Text(0, 0, 'PDGR3'),
#  Text(0, 0, 'RSID3'),
#  Text(0, 0, 'MDNE3'),
#  Text(0, 0, 'VIVR3'),
#  Text(0, 0, 'AZEV3'),
#  Text(0, 0, 'AZEV4'),
#  Text(0, 0, 'TCSA3'),
#  Text(0, 0, 'ETER3'),
#  Text(0, 0, 'GFSA3'),
#  Text(0, 0, 'HBOR3'),
#  Text(0, 0, 'MTRE3'),
#  Text(0, 0, 'MILS3'),
#  Text(0, 0, 'CALI3'),
#  Text(0, 0, 'CALI4'),
#  Text(0, 0, 'LPSB3'),
#  Text(0, 0, 'PTBL3'),
#  Text(0, 0, 'RDNI3'),
#  Text(0, 0, 'BBRK3'),
#  Text(0, 0, 'CRDE3'),
#  Text(0, 0, 'TCNO4'),
#  Text(0, 0, 'TCNO3'),
#  Text(0, 0, 'SOND6'),
#  Text(0, 0, 'SOND3'),
#  Text(0, 0, 'SOND5'),
#  Text(0, 0, 'HAGA4'),
#  Text(0, 0, 'HAGA3'),
#  Text(0, 0, 'MEND5'),
#  Text(0, 0, 'MEND6')]

# %%
bx = construtoras.sort_values('Margem Bruta', ascending = False)[['Ticker', 'Margem Bruta']].set_index('Ticker').plot.bar(figsize = (15,8))
bx.set_xticklabels(bx.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
# Out:
# [Text(0, 0, 'AZEV4'),
#  Text(0, 0, 'AZEV3'),
#  Text(0, 0, 'LPSB3'),
#  Text(0, 0, 'MEND6'),
#  Text(0, 0, 'MEND5'),
#  Text(0, 0, 'CALI3'),
#  Text(0, 0, 'CALI4'),
#  Text(0, 0, 'BBRK3'),
#  Text(0, 0, 'JFEN3'),
#  Text(0, 0, 'JHSF3'),
#  Text(0, 0, 'EZTC3'),
#  Text(0, 0, 'MDNE3'),
#  Text(0, 0, 'TRIS3'),
#  Text(0, 0, 'MILS3'),
#  Text(0, 0, 'DIRR3'),
#  Text(0, 0, 'TEND3'),
#  Text(0, 0, 'PTBL3'),
#  Text(0, 0, 'SOND5'),
#  Text(0, 0, 'SOND3'),
#  Text(0, 0, 'SOND6'),
#  Text(0, 0, 'MTRE3'),
#  Text(0, 0, 'CYRE3'),
#  Text(0, 0, 'MRVE3'),
#  Text(0, 0, 'GFSA3'),
#  Text(0, 0, 'RDNI3'),
#  Text(0, 0, 'EVEN3'),
#  Text(0, 0, 'VIVR3'),
#  Text(0, 0, 'HAGA4'),
#  Text(0, 0, 'HAGA3'),
#  Text(0, 0, 'TCNO4'),
#  Text(0, 0, 'TCNO3'),
#  Text(0, 0, 'ETER3'),
#  Text(0, 0, 'HBOR3'),
#  Text(0, 0, 'TCSA3'),
#  Text(0, 0, 'PDGR3'),
#  Text(0, 0, 'RSID3'),
#  Text(0, 0, 'CRDE3')]

# %%
energias = base[base['Setor'] == 'Energia Elétrica']
energias
# Out:
#     Ticker   Tipo                            Empresa             Setor  \
# 17   CPLE5    PNA                          COPEL PNA  Energia Elétrica
# 22   CESP5    PNA  CESP CIA ENERGETICA SAO PAULO PNA  Energia Elétrica
# 23   CESP6    PNB  CESP CIA ENERGETICA SAO PAULO PNB  Energia Elétrica
# 26   CESP3     ON   CESP CIA ENERGETICA SAO PAULO ON  Energia Elétrica
# 40   CMIG4  PN N1                        CEMIG PN N1  Energia Elétrica
# ..     ...    ...                                ...               ...
# 410  CEED4  PN N1                        CEEED PN N1  Energia Elétrica
# 412  CEPE3     ON                           CELPE ON  Energia Elétrica
# 413  COCE6    PNB        CIA ENERG CEARA  COELCE PNB  Energia Elétrica
# 420  ELET5    PNA                     ELETROBRÁS PNA  Energia Elétrica
# 421  EQPA6    PNB                      EQTL PARA PNB  Energia Elétrica
#
#              Subsetor  Valor de Mercado  Valor da Firma  \
# 17   Energia Elétrica      7.528260e+09    1.615540e+10
# ...

# %%
bx = energias.sort_values('EBIT', ascending = False)[['Ticker', 'EBIT']].set_index('Ticker').plot.bar(figsize = (30,8))
bx.set_xticklabels(bx.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
plt.show()

# %%
bx = energias.sort_values('ROE', ascending = True)[['Ticker', 'ROE']].set_index('Ticker').plot.bar(figsize = (30,8))
bx.set_xticklabels(bx.get_xticklabels(), rotation = 45, horizontalalignment = 'right')
plt.show()
